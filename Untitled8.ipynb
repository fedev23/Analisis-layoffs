# %% [markdown]
# <a href="https://colab.research.google.com/github/fedev23/Analisis-layoffs/blob/main/Untitled8.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns
import plotly.express as px

# %%
df = pd.read_csv('layoffs.csv')

# %%
df.head()
# Out:
#    Id     Nombre   Apellido       Area Fecha comienzo   Fecha fin Nivel  \
# 0   1     Romina      Brito  Marketing     03/05/2018  12/31/2018    N3
# 1   2      Pedro      Lujan    Compras     03/06/2017  12/31/2021    N3
# 2   3       Juan   Albornoz         IT     06/04/2018  04/30/2019    N4
# 3   4  Sebastian   González    Legales     05/07/2018  05/30/2021    N2
# 4   5     Franco  Rodríguez  Marketing     05/01/2017  11/30/2017    N5
#
#   Grupo recruitment  Tiempo recruitment Rango Salarial RS competencia  \
# 0           Grupo B                   3        Rango 3        Rango 3
# 1           Grupo B                   3        Rango 2        Rango 2
# 2           Grupo C                   4        Rango 4        Rango 4
# 3           Grupo A                   4        Rango 2        Rango 2
# 4           Grupo C                   6        Rango 5        Rango 4
#
#    Manager Realizo Cursos
# 0        1             SI
# 1        2             SI
# 2        5             NO
# ...

# %%
from plotnine import ggplot, geom_bar, aes

plot = ggplot(data=df) + \
       geom_bar(mapping=aes(x='Area', fill='Rango_Salarial	'), position='fill')

print(plot)
# Out:
# /usr/local/lib/python3.10/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 9 (	) missing from current font.

# %% [markdown]
# # Informacion sobre los salarios segun su area.

# %%
df
# Out:
#     Id     Nombre   Apellido        Area Fecha_comienzo  Fecha_fin Nivel  \
# 0    1     Romina      Brito   Marketing     2018-03-05 2018-12-31    N3
# 1    2      Pedro      Lujan     Compras     2017-03-06 2021-12-31    N3
# 2    3       Juan   Albornoz          IT     2018-06-04 2019-04-30    N4
# 4    5     Franco  Rodríguez   Marketing     2017-05-01 2017-11-30    N5
# 5    6   Catalina      Gómez  Producción     2019-04-01 2022-03-31    N2
# 6    7   Anabella  Fernández      Ventas     2020-07-06 2021-03-31    N4
# 7    8  Francesca      López     Compras     2017-01-02 2021-06-30    N3
# 8    9    Nicolas   Martínez          IT     2021-01-04 2021-11-30    N2
# 9   10        Ana       Diaz          IT     2017-03-06 2020-11-30    N4
# 10  11    Roberto      Pérez   Marketing     2019-07-01 2022-04-30    N5
# 11  12       Luis    Sánchez      Ventas     2020-07-13 2020-12-31    N5
# 12  13  Alejandro     Romero          IT     2020-06-01 2022-02-28    N3
# ...

# %%
df.rename(columns={'Grupo recruitment': 'Grupo_recruitment'}, inplace=True)
df.rename(columns={'Tiempo recruitment': 'Tiempo_recruitment'}, inplace=True)
df.rename(columns={'Rango Salarial': 'Rango_Salarial'}, inplace=True)
df.rename(columns={'Fecha comienzo': 'Fecha_comienzo'}, inplace=True)
df.rename(columns={'Fecha fin': 'Fecha_fin'}, inplace=True)
data.rename(columns={'Realizo Cursos': 'Realizo_Cursos'}, inplace=True)

# %%
count_by_type = df['Grupo_recruitment'].value_counts()
fig, ax = plt.subplots()
ax.bar(count_by_type.index, count_by_type.values)
ax.set_xlabel('cantidad de reclutados por grupo ')
plt.show()

# %%
fig = px.box(data, x="Grupo_recruitment", y="Tiempo_Transcurrido")
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# # ***Como podemos ver el grupo C de reclutadores contrata personas que se quedan poco tiempo en la empresa.***

# %%
count_by_type = df['Area'].value_counts()
fig, ax = plt.subplots()
ax.bar(count_by_type.index, count_by_type.values)
ax.set_xlabel('cantidad de reclutados por area')
plt.show()

# %%
data1 = df
data1["Fecha_comienzo"] = pd.to_datetime(data1["Fecha_comienzo"], format="%m/%d/%Y")
data1["Fecha_fin"] = pd.to_datetime(data1["Fecha_fin"], format="%m/%d/%Y")

# %%
data = df
data["Fecha_comienzo"] = pd.to_datetime(data1["Fecha_comienzo"], format="%m/%d/%Y")
data["Fecha_fin"] = pd.to_datetime(data1["Fecha_fin"], format="%m/%d/%Y")

# %%
data1['Tiempo_Transcurrido'] = (data1  ['Fecha_fin' ]-  data1  ['Fecha_comienzo' ]).dt.days

# %%
fila_a_eliminar = 3
data = data1.drop(fila_a_eliminar)

# %%
fig = px.box(data, x="Area", y="Tiempo_Transcurrido")
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
fig = px.box(data, x="Rango_Salarial", y="Tiempo_Transcurrido")
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# # ***El tiempo transcurrido en la empresa no  parece estar determinado por el rango salarial***

# %%
import matplotlib.pyplot as plt

total_volume_by_year = df.groupby('Realizo_Cursos')['Tiempo_Transcurrido'].sum()

# Crear la figura y los ejes
fig, ax = plt.subplots()


# Crear el gráfico de barras
ax.bar(total_volume_by_year.index, total_volume_by_year.values)

# Establecer etiquetas y título
ax.set_xlabel('relizacion de cursos')

# Mostrar el gráfico
plt.show()

# %% [markdown]
# # ***Las personas que realizaron cursos, se quedaron mas tiempo en la empresa***

# %%
fig = px.box(data, x="Manager", y="Tiempo_Transcurrido")
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# ## ***El manager 2 de compras es el que mayor retencion de personal tiene.***

# %%
fig = px.box(data, x="Realizo_Cursos", y="Tiempo_Transcurrido")
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# ##  La media de tiempo en la empresa, de las personas que realizaron cursos es mayor a la media del tiempo en la empresa de las personas que no realizaron

# %%
fig = px.box(data1, x="Grupo_recruitment", y="Tiempo_Transcurrido")
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
from plotnine import ggplot, geom_bar, aes

plot = ggplot(data=data) + \
       geom_bar(mapping=aes(x='Nivel', fill='Rango_Salarial	'), position='fill')

print(plot)
# Out:
# /usr/local/lib/python3.10/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 9 (	) missing from current font.
